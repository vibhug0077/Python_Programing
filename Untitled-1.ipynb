# %%
a ={20,30,40, 20 ,20 ,20}

# %%
a
# Out:
# {20, 30, 40}

# %%
type(a)
# Out:
# set

# %%
a
# Out:
# {20, 30, 40}

# %%
for item in a:
    print(item)
# Out:
# 40
# 20
# 30

# %%
b ={30,40,"A",60}

# %%
a.intersection(b)
# Out:
# {30, 40}

# %%
b
# Out:
# {30, 40, 60, 'A'}

# %%
a ={[[1,2,3],[4,5,6],[8,9,10]]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a ={[[1,2,3],[4,5,6],[8,9,10]]}
#
# TypeError: unhashable type: 'list'

# %%
a = sql.t0_set()

# %%
3.0 + True
# Out:
# 4.0

# %%
a =2

# %%
type(a)
# Out:
# int

# %%
a =2.0

# %%
type(a)
# Out:
# float

# %%
a ="Zero"

# %%
type(a)
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
a = "String"

# %%
a.upper()
# Out:
# 'STRING'

# %%
a ={"20",30,"20",40,20}

# %%
a
# Out:
# {20, '20', 30, 40}

# %%
b ={30,50}

# %%
a.intersection(b)
# Out:
# {30}

# %%
type(a.union(b))
# Out:
# set

# %%
a.union(b)
# Out:
# {20, '20', 30, 40, 50}

# %%
l =["Vibhu", 209, False, [12,3]]

# %%
for item in "77":
    print(item)
# Out:
# 7
# 7

# %%
for item in l:
    print(item)
# Out:
# Vibhu
# 209
# False
# [12, 3]

# %%
a_str = "STring"

# %%
a_str[0]
# Out:
# 'S'

# %%
len(a_str)
# Out:
# 6

# %%
a_str[len(a_str)-1]
# Out:
# 'g'

# %%
n = len(a_str)

# %%
a_str[n-1]
# Out:
# 'g'

# %%
a_str[-1]
# Out:
# 'g'

# %%
l =[1,2,3,4]

# %%
n = len(l)
print(n)
# Out:
# 4

# %%
l[n-1]
# Out:
# 4

# %%
for item in l:
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %%
a ={"Vibhu":38, "Rahul":50, "harry":60}

# %%
a
# Out:
# {'Vibhu': 38, 'Rahul': 50, 'harry': 60}

# %%
type(a)
# Out:
# dict

# %%
for item1, item2 in a.items():
    print(item1, item2)
# Out:
# Vibhu 38
# Rahul 50
# harry 60

# %%
for item1, item2 in a:
    print(item1, item2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 for item1, item2 in a:
#       2     print(item1, item2)
#
# ValueError: too many values to unpack (expected 2)

# %%
a["Vibhu"]=40

# %%
a
# Out:
# {'Vibhu': 40, 'Rahul': 50, 'harry': 60}

# %%
a ="string"

# %%
a[3]
# Out:
# 'i'

# %%
a[3]="h"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 a[3]="h"
#
# TypeError: 'str' object does not support item assignment

# %%
l=[12,3,4,5]

# %%
l[2] =5

# %%
l
# Out:
# [12, 3, 5, 5]

# %%
# Uncomment and run this cell in notebook:
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Hello "Vibhu"

# %%
for item in range(2,6):
    print(item)
# Out:
# 2
# 3
# 4
# 5

# %%
l = [1,2,3,4,5]

# %%
len(l)
# Out:
# 5

# %%
for item in range(len(l)):
    print(l[item])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in l:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in range(len(l)):
    print(l[item])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count =0
a= True
while a == True:
    print("Value of Count", count)
    count = count+1
    if count ==20:
        a = False
# Out:
# Value of Count 0
# Value of Count 1
# Value of Count 2
# Value of Count 3
# Value of Count 4
# Value of Count 5
# Value of Count 6
# Value of Count 7
# Value of Count 8
# Value of Count 9
# Value of Count 10
# Value of Count 11
# Value of Count 12
# Value of Count 13
# Value of Count 14
# Value of Count 15
# Value of Count 16
# Value of Count 17
# Value of Count 18
# Value of Count 19
