# %% [markdown]
# # This is my 1st Assignment
# ## Name : Vibhu Gautam
# ### SAP ID : 500012312

# %%
x = 20
y =30
print(x+y)
# Out:
# 50

# %%
def square(x):
    return x * x

print(square(5))
# Out:
# 25
